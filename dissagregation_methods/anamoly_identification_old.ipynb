# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import IsolationForest
from scipy.linalg import lstsq
from sklearn.model_selection import train_test_split
import cvxpy as cp
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401

# %%
df_data = pd.read_parquet("../training_data/initial_dataset.parquet")
df_train_detached = pd.read_parquet(
    "../training_data/data_detached_with_weather.parquet")
type(df_data)
type(df_train_detached)
df_train_detached

unique_ids = df_train_detached["Property_ID"].unique()
id_use = unique_ids[0]
df_house = pd.read_csv('../training_data/home_characteristics.csv')

# List of columns to check for missingness
cols = [
    "Bedrooms", "Floor_Height", "Habitable_Rooms", "House_Age",
    "House_Form", "No_Storeys", "No_Underfloor",
    "Total_Floor_Area", "Wall_Type", "MCS_DHWAnnual","HP_Size_kW"
]

# calculate min capacity in home 
cp_air = 1.005  #kJ/kgK
rho_air = 1.225  # kg/m^3
kj_to_kWh = 1/3600
df_house["Volume"] = df_house["Total_Floor_Area"] * df_house["Floor_Height"]
df_house["Min Capacity"] = df_house["Volume"] * cp_air * rho_air * kj_to_kWh

df_home_values = df_house[df_house["Property_ID"].isin(unique_ids)]

summary = df_home_values[["Property_ID", "Min Capacity"]].drop_duplicates()
print(summary)

home_dict = df_home_values.set_index("Property_ID").to_dict(orient="index")
# Out:
#      Property_ID  Min Capacity
# 76       EOH3196      0.086941
# 318      EOH0413      0.094570
# 585      EOH2329      0.099645
# 736      EOH1637      0.088733
# 1149     EOH3154      0.116411
# 1156     EOH2675      0.124696
# 1569     EOH1485      0.115696
# 1692     EOH0546      0.088239
# 2066     EOH0279      0.138493
# 2381     EOH1703      0.074688

# %%
df_single = df_train_detached[
df_train_detached["Property_ID"] == id_use].copy()

#re-adjust Heat Pump Diff and add temp differences
df_single["Heat_Pump_Energy_Output_Diff"] = df_single[
    "Heat_Pump_Energy_Output"].diff()
df_single["Internal_Temperature_Diff"] = df_single[
    "Internal_Air_Temperature"].diff()
df_single["Internal_Ambient_Temperature_Diff"] = \
    (df_single["External_Air_Temperature"] -
     df_single["Internal_Air_Temperature"])

# 1. Drop columns with almost all missing data (e.g., more than 90% missing)
threshold = 0.90 * len(df_single)
df_single_cleaned = df_single.dropna(axis=1, thresh=threshold)
#print("Columns dropped due to high missing values:")
#print(df_single.columns.difference(df_single_cleaned.columns).tolist())

df_single = df_single_cleaned

#print("\nColumns remaining after dropping highly missing columns:")
#print(df_single.columns.tolist())

df_single = df_single.set_index('Timestamp')
df_single = df_single.sort_index()

# Apply interpolation with a limit of 4 (for 2 hours of half-hourly data)
numeric_cols = df_single.select_dtypes(include=['number']).columns
df_single_numeric_interpolated = df_single[numeric_cols].interpolate(
    method='time', limit=4, limit_direction='both')

df_single_interpolated = df_single.copy()
df_single_interpolated[numeric_cols] = df_single_numeric_interpolated

# After interpolation, drop rows that still contain NaN values (meaning they were missing for > 2 hours)
initial_rows = len(df_single_interpolated)
df_single_processed = df_single_interpolated.dropna()

# %%
df_heating_single = df_single_processed.copy()

# Time range
t_start = pd.to_datetime("2021-10-01 00:00:00")
t_end = pd.to_datetime("2022-3-31 23:59:00")
df_heating_only = df_heating_single[
    (df_heating_single.index >= t_start) & (df_heating_single.index <= t_end)
].copy()

df_heating_only.drop("Property_ID", axis=1, inplace=True)
df_heating_only.drop("half-hour", axis=1, inplace=True)
df_heating_only.drop("Date", axis=1, inplace=True)
df_heating_only.drop("has_data", axis=1, inplace=True)


t_step_try = [1, 3, 6, 12, 24]

for i in t_step_try:
    df_numeric = df_heating_only.select_dtypes(include='number')

    # Resample and compute mean
    df_resampled = df_numeric.resample(f'{i}h').mean()

    # Extract variables
    delta_T_a_heat = df_resampled["Internal_Ambient_Temperature_Diff"]
    q_heat_only = df_resampled["Heat_Pump_Energy_Output_Diff"]
    delta_T_i_heat = df_resampled["Internal_Temperature_Diff"]
    T_ambient = df_resampled["External_Air_Temperature"]
    # Create new scatter plot
    plt.figure()
    plt.scatter(delta_T_a_heat, q_heat_only)
    plt.title(f"Ambient Delta Scatter Plot for Time Step = {i} Hour(s)")
    plt.xlabel("Delta Temperature")
    plt.ylabel("Heat Input Q")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
    plt.figure()
    plt.scatter(T_ambient, q_heat_only)
    plt.title(f"Ambient Scatter Plot for Time Step = {i} Hour(s)")
    plt.xlabel("Delta Temperature")
    plt.ylabel("Heat Input Q")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
    plt.figure()
    plt.scatter(delta_T_i_heat, q_heat_only)
    plt.title(f"Internal Delta Scatter Plot for Time Step = {i} Hour(s)")
    plt.xlabel("Delta Temperature")
    plt.ylabel("Heat Input Q")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
    fig = plt.figure()
    ax  = fig.add_subplot(111, projection='3d')
    p   = ax.scatter(
        delta_T_i_heat,
        q_heat_only,
        T_ambient,           # third axis
        c=T_ambient,
        cmap='viridis',
        depthshade=True,
        s=40
    )
    ax.set_xlabel("Δ Temperature")
    ax.set_ylabel("Heat Input Q")
    ax.set_zlabel("Ambient Temperature (°C)")
    fig.colorbar(p, ax=ax, pad=0.1, label='Ambient T')
    plt.title(f"3D Scatter for Time Step = {i} Hour(s)")
    plt.tight_layout()
    plt.show()

# %%
# 1. Subset to your desired time range
t_start = pd.to_datetime("2021-10-01 00:00:00")
t_end   = pd.to_datetime("2022-03-31 23:59:00")
df = df_heating_single.loc[t_start:t_end].copy()

# 2. Add the sinusoidal time‐of‐day features
df['sin_h'] = np.sin(2 * np.pi * df.index.hour / 24)
df['cos_h'] = np.cos(2 * np.pi * df.index.hour / 24)

# 3. Resample to 6-hour windows
agg_dict = {
    'Heat_Pump_Energy_Output_Diff': 'sum',   # total heat input
    'Internal_Ambient_Temperature_Diff': 'mean',
    'External_Air_Temperature': 'mean',
    'Internal_Temperature_Diff': 'mean',
    'Internal_Air_Temperature': 'mean',
    'sin_h': 'mean',
    'cos_h': 'mean'
}
df6h = df.resample('2h').agg(agg_dict).dropna()

# 4. Prepare your feature matrix
features = [
    'Heat_Pump_Energy_Output_Diff',
    'Internal_Ambient_Temperature_Diff',
    'External_Air_Temperature',
    'Internal_Temperature_Diff',
    'Internal_Air_Temperature',
    'sin_h',
    'cos_h'
]
X = df6h[features]

# 5. Fit the Isolation Forest (no `behaviour` parameter)
iso = IsolationForest(
    n_estimators=100,
    contamination=0.20,    # expecting ~x% anomalies
    random_state=42
)
iso.fit(X)

# 6. Score and flag anomalies
df6h['anomaly_score'] = iso.decision_function(X)   # higher → more normal
df6h['is_anomaly']    = iso.predict(X) == -1       # -1 = anomaly

# 7. Quick summary
print(f"Total windows:    {len(df6h)}")
print(f"Anomalies found:  {df6h['is_anomaly'].sum()}")

# 8. Plot the 6-h heat input with anomalies highlighted
plt.figure(figsize=(12, 4))
plt.plot(df6h.index, df6h['Heat_Pump_Energy_Output_Diff'], label='6-h Heat Input')
plt.scatter(
    df6h.index[df6h['is_anomaly']],
    df6h.loc[df6h['is_anomaly'], 'Heat_Pump_Energy_Output_Diff'],
    color='red',
    label='Anomaly'
)
plt.title("6-Hour Aggregated Heat Input – Isolation Forest Anomalies")
plt.xlabel("Time")
plt.ylabel("Heat Pump Energy Output (Diff)")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Total windows:    2184
# Anomalies found:  437

# %%
# ──────────────────────────────────────────────────────────────────────────────
# 9. Identify which calendar days have ≥1 anomaly
df6h['date'] = df6h.index.date
anomaly_days = np.unique(df6h.loc[df6h['is_anomaly'], 'date'])
print(f"\nNumber of days with at least one anomaly: {len(anomaly_days)}")

# 10. Compute daily metrics (from the 6-h windows)
daily_metrics = (
    df6h
    .groupby('date')
    .agg(daily_heat_input       = ('Heat_Pump_Energy_Output_Diff', 'sum'),
         mean_external_temp     = ('External_Air_Temperature',       'mean'),
         mean_internal_temp     = ('Internal_Air_Temperature',       'mean'))
)

# 11. Filter to only those anomaly days
daily_anomaly = daily_metrics.loc[anomaly_days]

# 12. Show a few example days
print("\nExample anomaly days and their daily metrics:")
print(daily_anomaly.sample(5))    # pick 5 random example dayse
# Out:
# Number of days with at least one anomaly: 113
#
# Example anomaly days and their daily metrics:
#             daily_heat_input  mean_external_temp  mean_internal_temp
# date
# 2022-03-21            42.363            3.955000           16.649375
# 2022-01-30            66.098            4.810417           16.703750
# 2022-01-05            76.280            1.881354           16.688958
# 2022-02-28            39.347            7.500417           16.714583
# 2021-11-29            69.730            3.551875           15.192500

# %%
anomaly_days[3]
# Out:
# datetime.date(2021, 10, 9)

# %%
# 1. Re-filter your original 30-min data to the same date range
df30 = df_heating_single.loc[t_start:t_end].copy()

# 2. Keep only the anomaly days via np.isin
mask = np.isin(df30.index.date, anomaly_days[3])
df30 = df30[mask]

# 3. Plot everything
fig, ax1 = plt.subplots(figsize=(14, 5))

# Heat input on primary y-axis
l1, = ax1.plot(
    df30.index,
    df30['Heat_Pump_Energy_Output_Diff'],
    label='Heat Input (30 min)',
)
ax1.set_xlabel('Time')
ax1.set_ylabel('Heat Input')
ax1.tick_params(axis='y')

# Temperature on a secondary y-axis
ax2 = ax1.twinx()
l2, = ax2.plot(
    df30.index,
    df30['External_Air_Temperature'],
    linestyle='--',
    label='Outdoor Temp'
)
l3, = ax2.plot(
    df30.index,
    df30['Internal_Air_Temperature'],
    linestyle=':',
    label='Indoor Temp'
)
ax2.set_ylabel('Temperature (°C)')
ax2.tick_params(axis='y')

# Combine legends
lines = [l1, l2, l3]
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='upper left')

plt.title('30-Minute Heat Input & Temperatures on Anomaly Days')
plt.tight_layout()
plt.show()

# %%
from darts import TimeSeries
from darts.models import NBEATSModel
from darts.dataprocessing.transformers import Scaler

# ────────────────────────────────────────────────────────────────────────────────
# 1) Load + Resample (e.g. 3-hour steps)
df = df_heating_single.loc["2021-10-01":"2022-03-31"].copy()
df['sin_h'] = np.sin(2*np.pi*df.index.hour/24)
df['cos_h'] = np.cos(2*np.pi*df.index.hour/24)

df_res = df.resample('3H').agg({
    'Heat_Pump_Energy_Output_Diff':'sum',
    'External_Air_Temperature':'mean',
    'Internal_Air_Temperature':'mean',
    'sin_h':'mean','cos_h':'mean'
}).dropna()

# 2) Create TimeSeries
ts_heat = TimeSeries.from_dataframe(df_res, value_cols='Heat_Pump_Energy_Output_Diff')
ts_exog = TimeSeries.from_dataframe(df_res, value_cols=[
    'External_Air_Temperature','Internal_Air_Temperature','sin_h','cos_h'
])

# 3) Train/val split & scaling
train_heat, val_heat = ts_heat.split_before(0.8)
train_exog,  val_exog  = ts_exog.split_before(0.8)

scaler_y   = Scaler(); scaler_exo = Scaler()
train_heat = scaler_y.fit_transform(train_heat)
val_heat   = scaler_y.transform(val_heat)
train_exog = scaler_exo.fit_transform(train_exog)
val_exog   = scaler_exo.transform(val_exog)

# 4) Instantiate & fit N-BEATS (with MC dropout)
history_hours       = 24
freq_hours          = 3
input_chunk_length  = history_hours // freq_hours
output_chunk_length = 1

model = NBEATSModel(
    input_chunk_length  = input_chunk_length,
    output_chunk_length = output_chunk_length,
    dropout             = 0.1,      # MC Dropout
    n_epochs            = 100,
    random_state        = 42,
    pl_trainer_kwargs   = {"accelerator":"cpu"}
)

model.fit(
    series               = train_heat,
    past_covariates      = train_exog,
    val_series           = val_heat,
    val_past_covariates  = val_exog,
    verbose              = True
)

# ────────────────────────────────────────────────────────────────────────────────
# 5) —— NEW BLOCK: Rolling 1-step Quantile Forecasts via MC Dropout —— #
# Out:
# /var/folders/fk/0m0g9qgs7y5fc0br86wht_1m0000gn/T/ipykernel_47513/2339842429.py:11: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df_res = df.resample('3H').agg({
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /Users/levipremer/PycharmProjects/uk_data_electric_heating/.venv/lib/python3.12/site-packages/pytorch_lightning/trainer/setup.py:177: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
#
#   | Name            | Type             | Params | Mode
# -------------------------------------------------------------
# 0 | criterion       | MSELoss          | 0      | train
# 1 | train_criterion | MSELoss          | 0      | train
# 2 | val_criterion   | MSELoss          | 0      | train
# 3 | train_metrics   | MetricCollection | 0      | train
# 4 | val_metrics     | MetricCollection | 0      | train
# 5 | stacks          | ModuleList       | 6.3 M  | train
# -------------------------------------------------------------
# 6.3 M     Trainable params
# 1.5 K     Non-trainable params
# 6.3 M     Total params
# 25.285    Total estimated model params size (MB)
# 486       Modules in train mode
# 0         Modules in eval mode
# /Users/levipremer/PycharmProjects/uk_data_electric_heating/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch 0: 100%|██████████| 37/37 [00:02<00:00, 18.50it/s, train_loss=0.0205]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 62.58it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 73.73it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 70.91it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 81.86it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 89.64it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 84.87it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 82.31it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 79.71it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 80.15it/s]
# Epoch 1: 100%|██████████| 37/37 [00:01<00:00, 18.92it/s, train_loss=0.00974, val_loss=0.0556]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 90.35it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 86.43it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 97.24it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 84.89it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 91.96it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 98.14it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 102.07it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 104.49it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 97.53it/s]
# Epoch 2: 100%|██████████| 37/37 [00:02<00:00, 18.01it/s, train_loss=0.00248, val_loss=0.0324]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 112.45it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 125.95it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 95.22it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 83.84it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 78.99it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 85.08it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 89.78it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 88.10it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 92.01it/s]
# Epoch 3: 100%|██████████| 37/37 [00:02<00:00, 17.84it/s, train_loss=0.0165, val_loss=0.0252]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 108.00it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 95.12it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 107.20it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 90.63it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 97.70it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 102.21it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 105.59it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 95.20it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 98.75it/s]
# Epoch 4: 100%|██████████| 37/37 [00:02<00:00, 17.45it/s, train_loss=0.0395, val_loss=0.0301]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 116.20it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 81.96it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 95.56it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 101.86it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 108.50it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 112.10it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 115.21it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 117.26it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 106.05it/s]
# Epoch 5: 100%|██████████| 37/37 [00:02<00:00, 17.68it/s, train_loss=0.0356, val_loss=0.028]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 110.06it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 81.97it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 94.53it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 103.46it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 90.89it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 96.60it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 101.79it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 103.87it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 107.65it/s]
# Epoch 6: 100%|██████████| 37/37 [00:02<00:00, 17.14it/s, train_loss=0.0632, val_loss=0.0289]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 113.57it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 80.44it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 90.92it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 99.36it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 88.92it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 95.26it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 99.44it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 102.69it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 106.72it/s]
# Epoch 7: 100%|██████████| 37/37 [00:02<00:00, 17.92it/s, train_loss=0.0738, val_loss=0.0646]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 122.01it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 82.75it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 94.48it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 84.01it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 79.31it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 85.64it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 90.24it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 94.14it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 92.46it/s]
# Epoch 8: 100%|██████████| 37/37 [00:02<00:00, 18.14it/s, train_loss=0.00568, val_loss=0.0275]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 57.51it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 59.68it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 68.35it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 77.61it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 84.27it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 89.55it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 94.66it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 98.48it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 98.55it/s]
# Epoch 9: 100%|██████████| 37/37 [00:02<00:00, 17.84it/s, train_loss=0.0052, val_loss=0.0251]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 106.95it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 124.90it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 131.28it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 133.69it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 112.09it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 101.04it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 104.84it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 107.92it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 101.51it/s]
# Epoch 10: 100%|██████████| 37/37 [00:02<00:00, 18.29it/s, train_loss=0.0278, val_loss=0.026]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 121.74it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 134.92it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 135.01it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 136.06it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 109.36it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 98.08it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 101.93it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 94.45it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 98.34it/s]
# Epoch 11: 100%|██████████| 37/37 [00:02<00:00, 18.35it/s, train_loss=0.0178, val_loss=0.0302]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 117.07it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 125.75it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 93.85it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 101.12it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 92.34it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 97.35it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 90.38it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 86.28it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 90.50it/s]
# Epoch 12: 100%|██████████| 37/37 [00:02<00:00, 18.37it/s, train_loss=0.00501, val_loss=0.0281]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 118.66it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 87.41it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 80.48it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 77.03it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 73.55it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 79.87it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 85.59it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 89.60it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 93.98it/s]
# Epoch 13: 100%|██████████| 37/37 [00:02<00:00, 17.50it/s, train_loss=0.00666, val_loss=0.0302]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 121.57it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 79.29it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 87.24it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 96.60it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 102.09it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 106.52it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 111.30it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 113.45it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 115.43it/s]
# Epoch 14: 100%|██████████| 37/37 [00:02<00:00, 16.13it/s, train_loss=0.0416, val_loss=0.0255]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 56.78it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 58.77it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 71.87it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 67.86it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 66.15it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 65.35it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 71.17it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 76.02it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 74.36it/s]
# Epoch 15: 100%|██████████| 37/37 [00:02<00:00, 17.73it/s, train_loss=0.0205, val_loss=0.0245]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 114.71it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 123.34it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 127.63it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 131.37it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 108.84it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 113.04it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 117.37it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 119.18it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 106.79it/s]
# Epoch 16: 100%|██████████| 37/37 [00:02<00:00, 16.95it/s, train_loss=0.083, val_loss=0.0255]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 82.99it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 67.85it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 81.54it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 91.10it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 98.23it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 95.77it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 100.31it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 104.07it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 95.21it/s]
# Epoch 17: 100%|██████████| 37/37 [00:02<00:00, 16.47it/s, train_loss=0.00979, val_loss=0.0435]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 65.52it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 88.90it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 100.21it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 81.70it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 75.90it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 81.63it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 77.61it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 81.74it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 80.26it/s]
# Epoch 18: 100%|██████████| 37/37 [00:02<00:00, 17.37it/s, train_loss=0.00466, val_loss=0.0235]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 119.39it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 124.56it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 132.30it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 132.73it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 135.21it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 136.99it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 117.75it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 120.72it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 108.96it/s]
# Epoch 19: 100%|██████████| 37/37 [00:02<00:00, 17.16it/s, train_loss=0.0109, val_loss=0.0257]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 110.47it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 126.77it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 130.02it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 134.06it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 136.63it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 137.40it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 139.04it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 119.51it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 108.12it/s]
# Epoch 20: 100%|██████████| 37/37 [00:02<00:00, 17.13it/s, train_loss=0.00594, val_loss=0.0237]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 90.60it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 69.05it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 65.43it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 62.85it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 70.35it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 76.75it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 76.00it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 80.42it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 84.26it/s]
# Epoch 21: 100%|██████████| 37/37 [00:02<00:00, 17.36it/s, train_loss=0.0128, val_loss=0.0232]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 118.87it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 133.00it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 133.76it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 134.08it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 135.49it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 124.70it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 127.43it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 127.79it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 129.15it/s]
# Epoch 22: 100%|██████████| 37/37 [00:02<00:00, 17.24it/s, train_loss=0.0199, val_loss=0.0262]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 105.50it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 75.17it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 70.10it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 79.90it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 87.34it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 92.02it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 97.19it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 89.24it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 92.56it/s]
# Epoch 23: 100%|██████████| 37/37 [00:02<00:00, 17.13it/s, train_loss=0.00857, val_loss=0.0256]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 121.51it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 133.38it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 94.37it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 101.20it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 107.91it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 111.82it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 99.45it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 91.99it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 96.07it/s]
# Epoch 24: 100%|██████████| 37/37 [00:02<00:00, 17.36it/s, train_loss=0.017, val_loss=0.0268]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 57.26it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 59.31it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 55.59it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 60.35it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 68.28it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 74.31it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 76.93it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 77.12it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 81.05it/s]
# Epoch 25: 100%|██████████| 37/37 [00:02<00:00, 17.68it/s, train_loss=0.0204, val_loss=0.0237]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 118.51it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 132.26it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 113.20it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 117.52it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 122.71it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 126.33it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 109.78it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 95.36it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 89.60it/s]
# Epoch 26: 100%|██████████| 37/37 [00:02<00:00, 16.61it/s, train_loss=0.00498, val_loss=0.0265]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 112.63it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 76.02it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 90.25it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 82.32it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 76.62it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 82.64it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 78.86it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 77.36it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 81.10it/s]
# Epoch 27: 100%|██████████| 37/37 [00:02<00:00, 17.81it/s, train_loss=0.0147, val_loss=0.0231]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 111.63it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 122.96it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 126.19it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 128.70it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 125.57it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 128.17it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 130.95it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 130.68it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 132.68it/s]
# Epoch 28: 100%|██████████| 37/37 [00:02<00:00, 17.69it/s, train_loss=0.0079, val_loss=0.0278]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 56.20it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 80.36it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 93.04it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 81.41it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 88.28it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 94.78it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 98.93it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 100.37it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 96.53it/s]
# Epoch 29: 100%|██████████| 37/37 [00:02<00:00, 17.40it/s, train_loss=0.0058, val_loss=0.024]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 114.80it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 129.47it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 114.50it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 118.34it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 122.41it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 126.09it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 126.83it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 127.70it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 113.80it/s]
# Epoch 30: 100%|██████████| 37/37 [00:02<00:00, 15.95it/s, train_loss=0.00751, val_loss=0.0249]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 62.90it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 69.52it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 66.41it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 75.93it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 83.56it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 88.52it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 74.38it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 67.16it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 61.69it/s]
# Epoch 31: 100%|██████████| 37/37 [00:02<00:00, 16.66it/s, train_loss=0.0168, val_loss=0.0238]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 112.31it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 124.34it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 116.71it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 122.53it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 124.19it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 125.53it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 127.39it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 128.21it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 113.23it/s]
# Epoch 32: 100%|██████████| 37/37 [00:02<00:00, 16.90it/s, train_loss=0.000415, val_loss=0.0223]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 51.36it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 72.51it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 83.77it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 92.33it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 95.51it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 85.06it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 79.98it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 74.99it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 72.27it/s]
# Epoch 33: 100%|██████████| 37/37 [00:02<00:00, 15.74it/s, train_loss=0.00101, val_loss=0.0249]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 53.20it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 57.06it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 70.29it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 74.83it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 71.61it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 70.31it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 75.93it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 80.07it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 82.11it/s]
# Epoch 34: 100%|██████████| 37/37 [00:02<00:00, 16.74it/s, train_loss=0.00353, val_loss=0.0239]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 57.49it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 61.23it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 62.88it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 73.37it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 80.72it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 76.44it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 81.82it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 86.17it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 83.05it/s]
# Epoch 35: 100%|██████████| 37/37 [00:02<00:00, 17.95it/s, train_loss=0.0246, val_loss=0.0244]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 58.81it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 61.39it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 62.54it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 71.73it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 79.14it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 85.17it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 90.06it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 94.66it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 98.28it/s]
# Epoch 36: 100%|██████████| 37/37 [00:02<00:00, 18.14it/s, train_loss=0.00215, val_loss=0.037]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 110.56it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 122.53it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 125.92it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 128.37it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 129.67it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 108.90it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 103.94it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 101.66it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 104.08it/s]
# Epoch 37: 100%|██████████| 37/37 [00:02<00:00, 16.94it/s, train_loss=0.00453, val_loss=0.0278]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 121.21it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 85.50it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 75.04it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 84.76it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 80.74it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 86.65it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 82.48it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 87.01it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 83.07it/s]
# Epoch 38: 100%|██████████| 37/37 [00:02<00:00, 16.73it/s, train_loss=0.013, val_loss=0.0245]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 119.33it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 128.78it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 130.29it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 135.57it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 138.70it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 123.48it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 109.71it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 100.30it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 104.25it/s]
# Epoch 39: 100%|██████████| 37/37 [00:02<00:00, 17.66it/s, train_loss=0.0189, val_loss=0.0307]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 122.29it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 130.40it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 136.51it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 138.90it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 138.03it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 129.91it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 112.16it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 102.20it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 95.74it/s]
# Epoch 40: 100%|██████████| 37/37 [00:02<00:00, 17.29it/s, train_loss=0.0328, val_loss=0.0242]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 117.74it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 84.13it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 77.10it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 88.22it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 82.49it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 79.45it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 76.59it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 81.44it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 84.56it/s]
# Epoch 41: 100%|██████████| 37/37 [00:01<00:00, 19.09it/s, train_loss=0.00307, val_loss=0.0232]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 123.97it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 137.52it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 96.68it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 85.94it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 94.03it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 100.81it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 105.34it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 109.36it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 112.59it/s]
# Epoch 42: 100%|██████████| 37/37 [00:02<00:00, 17.77it/s, train_loss=0.0057, val_loss=0.0276]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 117.36it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 125.68it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 132.46it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 115.74it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 118.38it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 112.07it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 100.17it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 104.40it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 107.40it/s]
# Epoch 43: 100%|██████████| 37/37 [00:02<00:00, 17.21it/s, train_loss=0.0128, val_loss=0.0235]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 120.41it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 79.05it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 80.42it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 74.29it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 70.90it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 76.85it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 81.78it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 86.11it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 82.57it/s]
# Epoch 44: 100%|██████████| 37/37 [00:01<00:00, 18.92it/s, train_loss=0.00874, val_loss=0.0258]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 126.23it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 139.02it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 144.25it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 147.95it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 150.81it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 152.81it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 154.44it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 155.60it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 156.71it/s]
# Epoch 45: 100%|██████████| 37/37 [00:02<00:00, 17.64it/s, train_loss=0.00471, val_loss=0.0256]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 116.41it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 129.11it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 120.79it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 98.84it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 104.01it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 109.70it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 113.70it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 117.20it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 120.14it/s]
# Epoch 46: 100%|██████████| 37/37 [00:02<00:00, 16.82it/s, train_loss=0.00338, val_loss=0.0262]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 51.97it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 77.16it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 91.67it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 101.52it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 107.11it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 112.30it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 116.28it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 118.00it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 121.20it/s]
# Epoch 47: 100%|██████████| 37/37 [00:02<00:00, 16.88it/s, train_loss=0.0206, val_loss=0.0244]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 65.68it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 88.33it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 75.78it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 77.80it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 80.10it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 85.89it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 80.56it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 84.59it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 88.59it/s]
# Epoch 48: 100%|██████████| 37/37 [00:02<00:00, 17.32it/s, train_loss=0.00979, val_loss=0.0264]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 124.64it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 139.93it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 141.56it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 145.48it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 148.73it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 150.72it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 152.02it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 152.52it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 153.81it/s]
# Epoch 49: 100%|██████████| 37/37 [00:01<00:00, 18.96it/s, train_loss=0.002, val_loss=0.0232]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 126.33it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 141.77it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 142.93it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 146.40it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 148.27it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 149.85it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 151.05it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 152.07it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 153.53it/s]
# Epoch 50: 100%|██████████| 37/37 [00:01<00:00, 18.70it/s, train_loss=0.00349, val_loss=0.0269]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 122.28it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 134.71it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 139.69it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 143.31it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 112.41it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 116.84it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 120.38it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 122.19it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 125.02it/s]
# Epoch 51: 100%|██████████| 37/37 [00:01<00:00, 18.98it/s, train_loss=0.0324, val_loss=0.0255]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 115.17it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 95.16it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 80.18it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 90.47it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 96.73it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 102.17it/s]
# ...
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 98.04it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 88.48it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 93.73it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 86.87it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 91.29it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 94.61it/s]
# Epoch 85: 100%|██████████| 37/37 [00:02<00:00, 17.93it/s, train_loss=0.0015, val_loss=0.0289]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 57.37it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 80.23it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 72.82it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 74.12it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 82.26it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 77.06it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 82.73it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 86.88it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 83.33it/s]
# Epoch 86: 100%|██████████| 37/37 [00:02<00:00, 17.78it/s, train_loss=0.00226, val_loss=0.0249]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 62.45it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 86.51it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 77.14it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 71.31it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 73.91it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 80.34it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 85.38it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 90.23it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 94.40it/s]
# Epoch 87: 100%|██████████| 37/37 [00:02<00:00, 18.08it/s, train_loss=0.00466, val_loss=0.0282]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 57.94it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 82.27it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 74.00it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 69.23it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 67.42it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 66.26it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 71.80it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 70.33it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 74.90it/s]
# Epoch 88: 100%|██████████| 37/37 [00:02<00:00, 18.14it/s, train_loss=0.00289, val_loss=0.0269]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 114.78it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 123.98it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 130.91it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 133.56it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 134.31it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 112.36it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 116.60it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 104.70it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 108.12it/s]
# Epoch 89: 100%|██████████| 37/37 [00:02<00:00, 17.54it/s, train_loss=0.0108, val_loss=0.0258]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 62.94it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 70.87it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 83.61it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 91.61it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 96.44it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 93.63it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 96.29it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 98.13it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 99.51it/s]
# Epoch 90: 100%|██████████| 37/37 [00:01<00:00, 18.70it/s, train_loss=0.0133, val_loss=0.0275]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 115.85it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 126.65it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 108.33it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 116.05it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 120.65it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 121.95it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 124.42it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 125.14it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 126.54it/s]
# Epoch 91: 100%|██████████| 37/37 [00:01<00:00, 18.58it/s, train_loss=0.0146, val_loss=0.0271]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 119.86it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 132.12it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 98.47it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 106.52it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 108.12it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 111.00it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 100.16it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 92.41it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 95.98it/s]
# Epoch 92: 100%|██████████| 37/37 [00:02<00:00, 17.34it/s, train_loss=0.00376, val_loss=0.0246]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 110.98it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 120.28it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 127.80it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 129.09it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 131.94it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 132.40it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 132.47it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 134.76it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 136.92it/s]
# Epoch 93: 100%|██████████| 37/37 [00:02<00:00, 17.80it/s, train_loss=0.00538, val_loss=0.0279]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 117.90it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 128.42it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 94.68it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 85.93it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 93.23it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 99.13it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 102.46it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 106.51it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 109.20it/s]
# Epoch 94: 100%|██████████| 37/37 [00:02<00:00, 16.89it/s, train_loss=0.00235, val_loss=0.0267]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 112.97it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 117.27it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 116.20it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 120.97it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 117.06it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 119.52it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 118.60it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 119.55it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 121.56it/s]
# Epoch 95: 100%|██████████| 37/37 [00:02<00:00, 16.69it/s, train_loss=0.00506, val_loss=0.026]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 116.67it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 80.34it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 94.07it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 83.31it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 77.33it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 83.18it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 87.68it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 87.62it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 91.70it/s]
# Epoch 96: 100%|██████████| 37/37 [00:02<00:00, 16.47it/s, train_loss=0.00176, val_loss=0.0278]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 113.02it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 112.17it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 100.20it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 100.75it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 105.59it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 110.69it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 112.27it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 115.44it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 117.15it/s]
# Epoch 97: 100%|██████████| 37/37 [00:02<00:00, 17.00it/s, train_loss=0.0138, val_loss=0.0274]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 111.62it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 125.72it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 125.53it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 108.21it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 110.44it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 108.77it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 111.59it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 113.22it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 102.90it/s]
# Epoch 98: 100%|██████████| 37/37 [00:02<00:00, 16.05it/s, train_loss=0.00268, val_loss=0.0263]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 77.97it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 65.27it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 67.88it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 71.62it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 67.18it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 65.92it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 65.83it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 68.49it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 72.29it/s]
# Epoch 99: 100%|██████████| 37/37 [00:02<00:00, 16.32it/s, train_loss=0.00217, val_loss=0.0281]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Validation DataLoader 0:  11%|█         | 1/9 [00:00<00:00, 115.15it/s]
# Validation DataLoader 0:  22%|██▏       | 2/9 [00:00<00:00, 85.43it/s]
# Validation DataLoader 0:  33%|███▎      | 3/9 [00:00<00:00, 97.81it/s]
# Validation DataLoader 0:  44%|████▍     | 4/9 [00:00<00:00, 105.91it/s]
# Validation DataLoader 0:  56%|█████▌    | 5/9 [00:00<00:00, 112.55it/s]
# Validation DataLoader 0:  67%|██████▋   | 6/9 [00:00<00:00, 115.62it/s]
# Validation DataLoader 0:  78%|███████▊  | 7/9 [00:00<00:00, 119.16it/s]
# Validation DataLoader 0:  89%|████████▉ | 8/9 [00:00<00:00, 120.10it/s]
# Validation DataLoader 0: 100%|██████████| 9/9 [00:00<00:00, 110.83it/s]
# Epoch 99: 100%|██████████| 37/37 [00:02<00:00, 15.71it/s, train_loss=0.00217, val_loss=0.0269]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|██████████| 37/37 [00:02<00:00, 15.71it/s, train_loss=0.00217, val_loss=0.0269]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 64
#      61 start = 0.8
#      63 # 5.2) Generate probabilistic one-step forecasts over the historical period
# ---> 64 prob_forecast = model.historical_forecasts(
#      65     series            = ts_heat,
#      66     past_covariates   = ts_exog,
#      67     start             = start,
#      68     forecast_horizon  = 1,
#      69     stride            = 1,
#      70     retrain           = False,
#      71     verbose           = True,
#      72     mc_dropout        = True,
#      73     num_samples       = 200
#      74 )
#      76 # 5.3) Extract 5th, 50th, 95th percentile series
#      77 lower  = scaler_y.inverse_transform(prob_forecast.quantile_timeseries(0.05))
#
# File ~/PycharmProjects/uk_data_electric_heating/.venv/lib/python3.12/site-packages/darts/utils/utils.py:207, in _with_sanity_checks.<locals>.decorator.<locals>.sanitized_method(self, *args, **kwargs)
#     204 only_args, only_kwargs = {}, {}
#     205 for sanity_check_method in sanity_check_methods:
#     206     # Convert all arguments into keyword arguments
# --> 207     all_as_kwargs = getcallargs(method_to_sanitize, self, *args, **kwargs)
#     209     # Then separate args from kwargs according to the function's signature
#     210     only_args = all_as_kwargs.copy()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/inspect.py:1571, in getcallargs(func, *positional, **named)
#    1569 if kw not in possible_kwargs:
#    1570     if not varkw:
# -> 1571         raise TypeError("%s() got an unexpected keyword argument %r" %
#    1572                         (f_name, kw))
#    1573     arg2value[varkw][kw] = value
#    1574     continue
#
# TypeError: historical_forecasts() got an unexpected keyword argument 'mc_dropout'

# %%
# … after model.fit(…) …

# 1) determine your “backtest” start index (e.g. 80% in)
start_frac = 0.8
start_idx  = int(len(ts_heat) * start_frac)

# prepare lists for your bands
timestamps  = ts_heat.time_index[start_idx:]
lower_vals  = []
median_vals = []
upper_vals  = []

# 2) roll through each step and sample via MC dropout
for t in range(start_idx, len(ts_heat)):
    hist_series  = ts_heat[:t]
    hist_cov     = ts_exog[:t]

    # one‐step MC‐dropout forecast
    pf = model.predict(
        n               = 1,
        series          = hist_series,
        past_covariates = hist_cov,
        mc_dropout      = True,
        num_samples     = 200
    )

    # ← replace quantile_timeseries() with quantile(q)
    lower_vals.append( pf.quantile(0.05).values()[0][0] )
    median_vals.append(pf.quantile(0.50).values()[0][0])
    upper_vals.append( pf.quantile(0.95).values()[0][0] )

# 3) build time series for your bands
lower  = TimeSeries.from_times_and_values(timestamps, np.array(lower_vals))
median = TimeSeries.from_times_and_values(timestamps, np.array(median_vals))
upper  = TimeSeries.from_times_and_values(timestamps, np.array(upper_vals))

# 4) align the observed slice
obs = ts_heat[start_idx:]

# 5) anomaly mask = outside [lower, upper]
mask = (obs < lower) | (obs > upper)
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /Users/levipremer/PycharmProjects/uk_data_electric_heating/.venv/lib/python3.12/site-packages/pytorch_lightning/trainer/setup.py:177: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# /Users/levipremer/PycharmProjects/uk_data_electric_heating/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 12.94it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.58it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.50it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.79it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.38it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.30it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.15it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.64it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.27it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.53it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.45it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.15it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.49it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.34it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.77it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.41it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.47it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.59it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.66it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.39it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.73it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.49it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.64it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.93it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.50it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.05it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.57it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.76it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.49it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.00it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.15it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.82it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.35it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.59it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.30it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.93it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.87it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.41it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.76it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.35it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.77it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.16it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.59it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.98it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.14it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.07it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.55it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.80it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.70it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.89it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.71it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.89it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.47it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.17it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.73it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.68it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.88it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.03it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.43it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.76it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.22it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.90it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.21it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.68it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.74it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.87it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.67it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.10it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.40it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.17it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.15it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.15it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.98it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.13it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.66it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.21it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.47it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.28it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.36it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.48it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.19it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.25it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.43it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.08it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.05it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.82it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.81it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.77it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.97it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.07it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.77it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.67it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.21it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.78it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.22it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.50it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.90it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.64it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.31it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.10it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.47it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.86it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.89it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.53it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.98it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.67it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.00it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.34it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.84it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.51it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.51it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.48it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.99it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.52it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.55it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.38it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.60it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.53it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.85it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.69it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.79it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.49it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.25it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.55it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.48it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.79it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.52it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.21it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.16it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.72it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.76it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.98it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.64it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.81it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.40it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.81it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.73it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.70it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.44it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.16it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.29it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.18it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.82it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.45it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.47it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.86it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.95it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.11it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.03it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.00it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.71it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.83it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.53it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.99it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.82it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.84it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.51it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.03it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.79it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.75it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.29it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.84it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.09it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.37it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.38it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.89it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.59it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.43it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.30it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.41it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.96it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.10it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.14it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.93it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.23it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.86it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.08it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.00it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.87it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.50it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.05it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.87it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.38it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.84it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.04it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.69it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.48it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.67it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.94it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.48it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.78it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.46it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.52it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.84it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.72it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.87it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.39it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.48it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.30it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.03it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.57it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.37it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.31it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.97it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.45it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.80it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.60it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.85it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.82it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.78it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.74it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.46it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.54it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.05it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.66it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.18it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.84it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.45it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.88it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.77it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.37it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.51it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.93it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.57it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.74it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.04it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.64it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.63it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.69it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.83it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.19it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.17it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.26it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.38it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.82it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.66it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.14it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.47it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.35it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.48it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.89it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.95it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.73it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.12it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.94it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.20it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.63it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.12it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.87it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.69it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.29it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.95it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.75it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.65it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 18.10it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.58it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.36it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.60it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.67it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.91it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.94it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.22it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.00it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.50it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.46it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.43it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.32it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 14.63it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.94it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 16.42it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.67it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 19.44it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 21.74it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 15.84it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.81it/s]
# KeyError: 'Not all components found in time index.'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 45
#      43 # 6) now you can plot exactly as before:
#      44 window = slice("2022-03-01","2022-03-07")
# ---> 45 obs_s = obs[window]; low_s = lower[window]; upp_s = upper[window]; m_s = mask[window].df()
#      47 plt.figure(figsize=(14,5))
#      48 plt.plot(obs_s.time_index, obs_s.values(), label='Observed')
#
# File ~/PycharmProjects/uk_data_electric_heating/.venv/lib/python3.12/site-packages/darts/timeseries.py:5611, in TimeSeries.__getitem__(self, key)
#    5609 idx = self.components.get_indexer(pd.Index([key.start, key.stop]))
#    5610 if (idx < 0).any():
# -> 5611     raise_log(
#    5612         KeyError("Not all components found in time index."), logger
#    5613     )
#    5614 indexer = slice(idx[0], idx[-1] + 1)
#    5615 values = self._values[:, indexer]
#
# File ~/PycharmProjects/uk_data_electric_heating/.venv/lib/python3.12/site-packages/darts/logging.py:132, in raise_log(exception, logger)
#     129 message = str(exception)
#     130 logger.error(exception_type + ": " + message)
# --> 132 raise exception
#
# KeyError: 'Not all components found in time index.'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1) Define your window
start_ts = pd.Timestamp("2022-03-01 00:00:00")
end_ts   = pd.Timestamp("2022-03-07 23:59:59")

# 2) Slice each Darts TimeSeries
obs_ts   = obs.slice(start_ts, end_ts)
low_ts   = lower.slice(start_ts, end_ts)
med_ts   = median.slice(start_ts, end_ts)
upp_ts   = upper.slice(start_ts, end_ts)

# 3) Convert them to pandas.Series
obs_pd = pd.Series(obs_ts.values().flatten(),  index=obs_ts.time_index, name="obs")
med_pd = pd.Series(med_ts.values().flatten(),  index=med_ts.time_index, name="med")
low_pd = pd.Series(low_ts.values().flatten(),  index=low_ts.time_index, name="low")
upp_pd = pd.Series(upp_ts.values().flatten(),  index=upp_ts.time_index, name="upp")

# 4) Rebuild the anomaly mask in pandas
mask_pd = (obs_pd < low_pd) | (obs_pd > upp_pd)

# 5) Extract anomaly points
anom_idx  = mask_pd[mask_pd].index
anom_vals = obs_pd.loc[anom_idx]

# 6) Plot
plt.figure(figsize=(14,5))

plt.plot(obs_pd.index, obs_pd,      label="Observed")
plt.plot(med_pd.index, med_pd,      color="black", label="Median")
plt.plot(low_pd.index, low_pd,      "--",          label="5th pct")
plt.plot(upp_pd.index, upp_pd,      "--",          label="95th pct")
plt.fill_between(
    low_pd.index,
    low_pd.values,
    upp_pd.values,
    color="lightgray", alpha=0.3,
    label="Prediction Interval"
)

plt.scatter(
    anom_idx,
    anom_vals,
    color="red",
    label="Anomaly",
    zorder=5
)

plt.title(f"MC-Dropout N-BEATS Bands & Anomalies\n{start_ts.date()} to {end_ts.date()}")
plt.xlabel("Time")
plt.ylabel("Heat Pump Energy Output (Diff)")
plt.legend(loc="upper left")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1) Define your window endpoints
start_ts = pd.Timestamp("2022-03-01 00:00:00")
end_ts   = pd.Timestamp("2022-03-07 23:59:59")

# 2) Slice each Darts TimeSeries
obs_ts =    obs.slice(start_ts, end_ts)
low_ts =    lower.slice(start_ts, end_ts)
med_ts =    median.slice(start_ts, end_ts)
upp_ts =    upper.slice(start_ts, end_ts)
mask_ts =   mask.slice(start_ts, end_ts)

# 3) Build pandas Series directly
obs_pd  = pd.Series(obs_ts.values().flatten(),  index=obs_ts.time_index, name="obs")
med_pd  = pd.Series(med_ts.values().flatten(),  index=med_ts.time_index, name="median")
low_pd  = pd.Series(low_ts.values().flatten(),  index=low_ts.time_index, name="low")
upp_pd  = pd.Series(upp_ts.values().flatten(),  index=upp_ts.time_index, name="upp")
mask_pd = pd.Series(mask_ts.values().flatten(), index=mask_ts.time_index, name="mask").astype(bool)

# 4) Extract anomaly points
anom_idx  = mask_pd[mask_pd].index
anom_vals = obs_pd.loc[anom_idx]

# 5) Plot
plt.figure(figsize=(14,5))

plt.plot(obs_pd.index, obs_pd.values, label="Observed")
plt.plot(med_pd.index, med_pd.values, color="black", label="Median")
plt.plot(low_pd.index, low_pd.values,  "--",    label="5th pct")
plt.plot(upp_pd.index, upp_pd.values,  "--",    label="95th pct")
plt.fill_between(
    low_pd.index,
    low_pd.values,
    upp_pd.values,
    color="lightgray", alpha=0.3,
    label="Prediction Interval"
)
plt.scatter(
    anom_idx,
    anom_vals,
    color="red",
    label="Anomaly",
    zorder=5
)

plt.title(f"MC-Dropout N-BEATS Bands & Anomalies\n{start_ts.date()} to {end_ts.date()}")
plt.xlabel("Time")
plt.ylabel("Heat Pump Energy Output (Diff)")
plt.legend(loc="upper left")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 13
#      11 med_ts =    median.slice(start_ts, end_ts)
#      12 upp_ts =    upper.slice(start_ts, end_ts)
# ---> 13 mask_ts =   mask.slice(start_ts, end_ts)
#      15 # 3) Build pandas Series directly
#      16 obs_pd  = pd.Series(obs_ts.values().flatten(),  index=obs_ts.time_index, name="obs")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'slice'
